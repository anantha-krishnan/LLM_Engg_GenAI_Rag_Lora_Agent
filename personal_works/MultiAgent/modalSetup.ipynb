# %%
import modal

# %%
#!modal setup

# %%
from hello import app, hello, hello_europe

# %%
with app.run():
    reply=hello.local()
reply

# %%
from llama import app, generate

# %%
with modal.enable_output():
    with app.run():
        result=generate.remote("Life is a mystery, everyone must stand alone, I hear")
result

# %%
from pricer_ephemeral import app, price

# %%
with modal.enable_output():
    with app.run():
        result=price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
result

# %%
# !modal deploy -m pricer_service

# %%
pricer = modal.Function.from_name("pricer-service", "price")

# %%
pricer.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")

# %%
# !modal deploy -m pricer_service2
# Out:
# - Creating objects...
# \ Creating objects...
# / Creating objects...
# └── - Creating mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py:
#     Uploaded 0/1 files
# \ Creating objects...
# └── \ Creating mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py:
#     Uploaded 0/1 files
# / Creating objects...
# └── / Creating mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py:
#     Finalizing index of 1 files
# \ Creating objects...
# └── \ Creating mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py:
#     Finalizing index of 1 files
# Building image im-9nnnKBCO1XqUN0XKUpXBeh
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#
# => Step 0: FROM base
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#
# => Step 1: RUN python -m pip install accelerate bitsandbytes huggingface peft torch transformers
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Collecting accelerate
#   Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.10.1-py3-none-any.whl.metadata (19 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting bitsandbytes
#   Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl.metadata (11 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting huggingface
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl.metadata (2.9 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting peft
#   Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.17.1-py3-none-any.whl.metadata (14 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting torch
#   Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.8.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (30 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Collecting transformers
#   Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.56.0-py3-none-any.whl.metadata (40 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Collecting numpy<3.0.0,>=1.17 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting packaging>=20.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting psutil (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting pyyaml (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Collecting huggingface_hub>=0.21.0 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.34.4-py3-none-any.whl.metadata (14 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting safetensors>=0.4.3 (from accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting filelock (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting typing-extensions>=4.10.0 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/typing-extensions/typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting sympy>=1.13.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting networkx (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting jinja2 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting fsspec (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting nvidia-nccl-cu12==2.27.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting triton==3.4.0 (from torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.4.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/site-packages (from triton==3.4.0->torch) (65.5.1)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting tqdm (from peft)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2025.8.29-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Collecting requests (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.22.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface_hub>=0.21.0->accelerate)
#   Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.9-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting charset_normalizer<4,>=2 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (36 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting idna<4,>=2.5 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/idna/idna-3.10-py3-none-any.whl.metadata (10 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Collecting urllib3<3,>=1.21.1 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Collecting certifi>=2017.4.17 (from requests->transformers)
#   Downloading http://pypi-mirror.modal.local:5555/simple/certifi/certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Downloading http://pypi-mirror.modal.local:5555/simple/accelerate/accelerate-1.10.1-py3-none-any.whl (374 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/numpy/numpy-2.3.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 349.9 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/bitsandbytes/bitsandbytes-0.47.0-py3-none-manylinux_2_24_x86_64.whl (61.3 MB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 343.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/torch/torch-2.8.0-cp311-cp311-manylinux_2_28_x86_64.whl (888.1 MB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.1/888.1 MB 338.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cublas-cu12/nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 331.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-cupti-cu12/nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 335.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-nvrtc-cu12/nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 334.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cuda-runtime-cu12/nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 291.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cudnn-cu12/nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 329.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 330.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cufile-cu12/nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 391.0 MB/s eta 0:00:00
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-curand-cu12/nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 332.6 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 339.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 337.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-cusparselt-cu12/nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 339.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nccl-cu12/nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 332.2 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 336.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/nvidia-nvtx-cu12/nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/triton/triton-3.4.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.5 MB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 MB 335.3 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface/huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/peft/peft-0.17.1-py3-none-any.whl (504 kB)
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Downloading http://pypi-mirror.modal.local:5555/simple/transformers/transformers-4.56.0-py3-none-any.whl (11.6 MB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 341.5 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/huggingface-hub/huggingface_hub-0.34.4-py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.5/561.5 kB 331.0 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Downloading http://pypi-mirror.modal.local:5555/simple/hf-xet/hf_xet-1.1.9-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 355.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tokenizers/tokenizers-0.22.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 349.7 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/fsspec/fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/packaging/packaging-25.0-py3-none-any.whl (66 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/pyyaml/PyYAML-6.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (762 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 410.7 MB/s eta 0:00:00
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Downloading http://pypi-mirror.modal.local:5555/simple/regex/regex-2025.8.29-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (798 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.9/798.9 kB 224.8 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/safetensors/safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (485 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/sympy/sympy-1.14.0-py3-none-any.whl (6.3 MB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 342.4 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/mpmath/mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 414.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/tqdm/tqdm-4.67.1-py3-none-any.whl (78 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Downloading http://pypi-mirror.modal.local:5555/simple/typing-extensions/typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/filelock/filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/jinja2/jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/markupsafe/MarkupSafe-3.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Downloading http://pypi-mirror.modal.local:5555/simple/networkx/networkx-3.5-py3-none-any.whl (2.0 MB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 356.0 MB/s eta 0:00:00
# Downloading http://pypi-mirror.modal.local:5555/simple/psutil/psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/requests/requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/charset-normalizer/charset_normalizer-3.4.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (150 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# Downloading http://pypi-mirror.modal.local:5555/simple/idna/idna-3.10-py3-none-any.whl (70 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/urllib3/urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading http://pypi-mirror.modal.local:5555/simple/certifi/certifi-2025.8.3-py3-none-any.whl (161 kB)
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, huggingface, urllib3, typing-extensions, triton, tqdm, sympy, safetensors, regex, pyyaml, psutil, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, idna, hf-xet, fsspec, filelock, charset_normalizer, certifi, requests, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, huggingface_hub, torch, tokenizers, transformers, bitsandbytes, accelerate, peft
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# ...
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#
# Successfully installed MarkupSafe-3.0.2 accelerate-1.10.1 bitsandbytes-0.47.0 certifi-2025.8.3 charset_normalizer-3.4.3 filelock-3.19.1 fsspec-2025.7.0 hf-xet-1.1.9 huggingface-0.0.1 huggingface_hub-0.34.4 idna-3.10 jinja2-3.1.6 mpmath-1.3.0 networkx-3.5 numpy-2.3.2 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.3 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.8.90 packaging-25.0 peft-0.17.1 psutil-7.0.0 pyyaml-6.0.2 regex-2025.8.29 requests-2.32.5 safetensors-0.6.2 sympy-1.14.0 tokenizers-0.22.0 torch-2.8.0 tqdm-4.67.1 transformers-4.56.0 triton-3.4.0 typing-extensions-4.15.0 urllib3-2.5.0
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Saving image...
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Image saved, took 4.38s
# / Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#
# Built image im-9nnnKBCO1XqUN0XKUpXBeh in 80.69s
#
#
# - Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Building image im-8Vq5tYnjDFSwk4C4n4Imgf
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# / Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# \ Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
#
# => Step 0: FROM base
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#
# => Step 1: ENV HF_HUB_CACHE=/cache
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Saving image...
# | Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# | Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# - Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# Image saved, took 812.95ms
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
#
# Built image im-8Vq5tYnjDFSwk4C4n4Imgf in 2.02s
#
#
# \ Creating objects...
# └── 🔨 Created mount c:\Projects\github_llmengg\personal_works\MultiAgent\price
# | Creating objects...
# └── 🔨 Created mount
#     c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# └── - Creating function Pricer.*...
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# └── | Creating function Pricer.*...
# - Creating objects...
# ├── 🔨 Created mount
# │   c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# └── 🔨 Created function Pricer.*.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# └── 🔨 Created function Pricer.*.
# | Creating objects...
# ├── 🔨 Created mount
# │   c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# └── 🔨 Created function Pricer.*.
#
# ✓ Created objects.
# ├── 🔨 Created mount
# │   c:\Projects\github_llmengg\personal_works\MultiAgent\pricer_service2.py
# └── 🔨 Created function Pricer.*.
# ✓ App deployed in 89.211s! 🎉
#
# View Deployment:
# https://modal.com/apps/anandthescorpio/main/deployed/pricer-service

# %%
Pricer = modal.Cls.from_name("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(reply)
# Out:
# 133.0

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 2nd generation")
# Out:
# 299.0
