# %% [markdown]
# ## Predict Product Prices
#
# ### Week 7 Day 2
#
# Selecting our model and evaluating the base model against the task.
#
# Keep in mind: our base model has 8 billion params, quantized down to 4 bits
# Compared with GPT-4o at TRILLIONS of params!
#
# # IMPORTANT please read me!!
#
# When you run the pip installs below, you may get an error from pip complaining about an incompatible version of fsspec.
#
# You should ignore that error! The version of fsspec is the right version, needed by HuggingFace.
#
# If you ask ChatGPT, it will encourage you to pip install a more recent version of fsspec. But that would be problematic; HuggingFace will fail to load the dataset later with an obscure error about file systems.
#
# So please run the pip installs as they appear below, and look the other way if you get an error!

# %%
# pip installs - ignore the error message!

# !pip install -q --upgrade torch==2.5.1+cu124 torchvision==0.20.1+cu124 torchaudio==2.5.1+cu124 --index-url https://download.pytorch.org/whl/cu124
# !pip install -q --upgrade requests==2.32.3 bitsandbytes==0.46.0 transformers==4.48.3 accelerate==1.3.0 datasets==3.2.0 peft==0.14.0 trl==0.14.0 matplotlib
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 83.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 56.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 37.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 75.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 97.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 92.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 38.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 25.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 31.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 33.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 13.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.
# google-adk 1.12.0 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, TrainingArguments, set_seed
from peft import LoraConfig, PeftModel
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
import matplotlib.pyplot as plt

# %%
# Tokenizers

LLAMA_3_1 = "meta-llama/Meta-Llama-3.1-8B"
QWEN_2_5 = "Qwen/Qwen2.5-7B"
GEMMA_2 = "google/gemma-2-9b"
PHI_3 = "microsoft/Phi-3-medium-4k-instruct"

# Constants

BASE_MODEL = LLAMA_3_1
HF_USER = "ananthak86"
DATASET_NAME = f"{HF_USER}/lite-data"
MAX_SEQUENCE_LENGTH = 182
QUANT_4_BIT = True

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %matplotlib inline

# %% [markdown]
# ### Log in to HuggingFace
#
# If you don't already have a HuggingFace account, visit https://huggingface.co to sign up and create a token.
#
# Then select the Secrets for this Notebook by clicking on the key icon in the left, and add a new secret called `HF_TOKEN` with the value as your token.

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
def investigate_tokenizer(model_name):
  print("Investigating tokenizer for", model_name)
  tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
  for number in [0, 1, 10, 100, 999, 1000]:
    tokens = tokenizer.encode(str(number), add_special_tokens=False)
    print(f"The tokens for {number}: {tokens}")

# %%
# Now we will try this with each model: LLAMA_3_1, QWEN_2_5, GEMMA_2, PHI_3

investigate_tokenizer(PHI_3)
# Out:
# Investigating tokenizer for microsoft/Phi-3-medium-4k-instruct
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/568 [00:00<?, ?B/s]
# The tokens for 0: [29871, 29900]
# The tokens for 1: [29871, 29896]
# The tokens for 10: [29871, 29896, 29900]
# The tokens for 100: [29871, 29896, 29900, 29900]
# The tokens for 999: [29871, 29929, 29929, 29929]
# The tokens for 1000: [29871, 29896, 29900, 29900, 29900]

# %% [markdown]
# # Load our data
#
# We uploaded it to Hugging Face, so it's easy to retrieve it now

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/413 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/9.84M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/789k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
test[0]
# Out:
# {'text': 'How much does this cost to the nearest dollar?\n\nCOCIDE 50 Pack Gas Burner Liners Aluminum Foil Square Stove Burner Covers Range Protectors Bib Liners Disposable Gas Burner Bibs Gas Top Liner Stove Aluminum Foil Drip Pans Easy Clean - (8.5 Square)\nNO MORE SCRUBBING THE STOVE - Stove burner covers that keep your stove clean at any time. Never scrape or clean the surface of your gas top for removing drips, spills or grease. Stove Easy Clean! AVOID HARSH CLEANSERS. No need to subject you skin to nasty chemicals. Simply discard and replace. Friendlier to the environment, and friendlier to your hands. SUPER EASY CLEANUP & DISPOSABLE - These range protectors can be used over and over again.\n\nPrice is $10.00',
#  'prices': 9.99}

# %% [markdown]
# # Prepare our Base Llama Model for evaluation
#
# Load our base model with 4 bit quantization and try out 1 example

# %%
## pick the right quantization

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

print(f"Memory footprint: {base_model.get_memory_footprint() / 1e9:.1f} GB")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# Memory footprint: 5.6 GB

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','').replace('$','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
extract_price("Price is $999 blah blah so cheap")
# Out:
# 999.0

# %%
def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = base_model.generate(inputs, max_new_tokens=4, attention_mask=attention_mask, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
model_predict(test[0]['text'])
# Out:
# 10.0

# %%
test[0]['text'].rsplit('\n\n', 1)[0]+'\n\nPrice is $'
# Out:
# 'How much does this cost to the nearest dollar?\n\nCOCIDE 50 Pack Gas Burner Liners Aluminum Foil Square Stove Burner Covers Range Protectors Bib Liners Disposable Gas Burner Bibs Gas Top Liner Stove Aluminum Foil Drip Pans Easy Clean - (8.5 Square)\nNO MORE SCRUBBING THE STOVE - Stove burner covers that keep your stove clean at any time. Never scrape or clean the surface of your gas top for removing drips, spills or grease. Stove Easy Clean! AVOID HARSH CLEANSERS. No need to subject you skin to nasty chemicals. Simply discard and replace. Friendlier to the environment, and friendlier to your hands. SUPER EASY CLEANUP & DISPOSABLE - These range protectors can be used over and over again.\n\nPrice is $'

# %% [markdown]
# # Evaluation!
#
# Trying out our base Llama 3.1 model against the Test dataset

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        #item.test_prompt().replace(" to the nearest dollar","").replace("\n\nPrice is $","")
        guess = self.predictor(datapoint["text"].rsplit('\n\n', 1)[0]+'\n\nPrice is $')
        truth = datapoint["prices"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(model_predict, test)
# Out:
# 1: Guess: $7.50 Truth: $9.99 Error: $2.49 SLE: 0.07 Item: COCIDE 50 Pack Gas B...
# 2: Guess: $7.50 Truth: $18.79 Error: $11.29 SLE: 0.71 Item: Aluminum Range Hood ...
# 3: Guess: $19.99 Truth: $169.99 Error: $150.00 SLE: 4.40 Item: TOREAD Portable Smal...
# 4: Guess: $25.00 Truth: $11.85 Error: $13.15 SLE: 0.50 Item: Clothes Dryer Belt R...
# 5: Guess: $25.00 Truth: $195.97 Error: $170.97 SLE: 4.10 Item: GE Genuine OEM Main ...
# 6: Guess: $299.99 Truth: $539.99 Error: $240.00 SLE: 0.34 Item: 24'' Single Wall Ove...
# 7: Guess: $19.99 Truth: $139.94 Error: $119.95 SLE: 3.63 Item: Stainless Steel Stov...
# 8: Guess: $25.99 Truth: $12.99 Error: $13.00 SLE: 0.43 Item: Waterdrop Plus Refri...
# 9: Guess: $7.99 Truth: $9.99 Error: $2.00 SLE: 0.04 Item: SAFELON 1 Pcs Baby S...
# 10: Guess: $7.99 Truth: $9.90 Error: $1.91 SLE: 0.04 Item: Hikwi Mini Digital L...
# 11: Guess: $7.99 Truth: $6.00 Error: $1.99 SLE: 0.06 Item: Caikeny Bees Cartoon...
# 12: Guess: $7.99 Truth: $92.90 Error: $84.91 SLE: 5.50 Item: Upgraded Detergent D...
# 13: Guess: $1.00 Truth: $16.00 Error: $15.00 SLE: 4.58 Item: Think Crucial Replac...
# 14: Guess: $7.00 Truth: $75.38 Error: $68.38 SLE: 5.09 Item: Whirlpool Washplate
# ...
# 15: Guess: $25.00 Truth: $50.51 Error: $25.51 SLE: 0.47 Item: FASJ Portable Washin...
# 16: Guess: $7.99 Truth: $10.99 Error: $3.00 SLE: 0.08 Item: (Only 1 PACK) Reusab...
# 17: Guess: $19.99 Truth: $23.99 Error: $4.00 SLE: 0.03 Item: 2-Pack Replacement f...
# 18: Guess: $25.99 Truth: $139.99 Error: $114.00 SLE: 2.73 Item: Upstreman 3.2 Cu.Ft ...
# 19: Guess: $7.99 Truth: $22.99 Error: $15.00 SLE: 0.96 Item: Ximoon 1043 Humidifi...
# 20: Guess: $7.99 Truth: $16.97 Error: $8.98 SLE: 0.48 Item: PureSpring Certified...
# 21: Guess: $19.99 Truth: $25.99 Error: $6.00 SLE: 0.06 Item: 279838 Dryer Heating...
# 22: Guess: $1.00 Truth: $86.61 Error: $85.61 SLE: 14.29 Item: Pitco Thermostat
# Pro...
# 23: Guess: $19.99 Truth: $39.50 Error: $19.51 SLE: 0.43 Item: Able KONE for Chemex...
# 24: Guess: $25.99 Truth: $35.99 Error: $10.00 SLE: 0.10 Item: 3 Sets Slide in Rang...
# 25: Guess: $25.00 Truth: $10.61 Error: $14.39 SLE: 0.65 Item: GOLDEN ICEPURE PLUS ...
# 26: Guess: $1.00 Truth: $7.66 Error: $6.66 SLE: 2.15 Item: GE Dishwasher Knob I...
# 27: Guess: $25.00 Truth: $21.99 Error: $3.01 SLE: 0.02 Item: 2-Pack Replacement f...
# 28: Guess: $7.99 Truth: $9.95 Error: $1.96 SLE: 0.04 Item: CoffeeStar – Reusabl...
# 29: Guess: $25.00 Truth: $27.99 Error: $2.99 SLE: 0.01 Item: WOWFEEL Rabbit Dishw...
# 30: Guess: $19.95 Truth: $30.00 Error: $10.05 SLE: 0.15 Item: Compatible Oven Bake...
# 31: Guess: $25.00 Truth: $189.62 Error: $164.62 SLE: 3.97 Item: Frigidaire Oven Igni...
# 32: Guess: $19.95 Truth: $109.95 Error: $90.00 SLE: 2.78 Item: Jura Glass Milk Cont...
# 33: Guess: $7.00 Truth: $23.99 Error: $16.99 SLE: 1.30 Item: Washing Machine Belt...
# 34: Guess: $7.00 Truth: $8.69 Error: $1.69 SLE: 0.04 Item: Supplying Demand Dis...
# 35: Guess: $7.00 Truth: $27.99 Error: $20.99 SLE: 1.66 Item: OEM LG Dryer Lint Fi...
# 36: Guess: $89.99 Truth: $129.99 Error: $40.00 SLE: 0.13 Item: WANAI Mini Fridge Du...
# 37: Guess: $7.50 Truth: $7.99 Error: $0.49 SLE: 0.00 Item: Replacement Water In...
# 38: Guess: $7.00 Truth: $22.49 Error: $15.49 SLE: 1.16 Item: Wholesale Sensors Re...
# 39: Guess: $7.99 Truth: $7.95 Error: $0.04 SLE: 0.00 Item: Reusable K Cups, 6 P...
# 40: Guess: $1.00 Truth: $15.99 Error: $14.99 SLE: 4.58 Item: Supplying Demand Dis...
# 41: Guess: $25.00 Truth: $59.95 Error: $34.95 SLE: 0.73 Item: UPGRADED Lifetime Ap...
# 42: Guess: $7.99 Truth: $99.14 Error: $91.15 SLE: 5.81 Item: GLOB PRO SOLUTIONS R...
# 43: Guess: $19.99 Truth: $22.99 Error: $3.00 SLE: 0.02 Item: Bluapple and VeggieZ...
# 44: Guess: $7.99 Truth: $17.99 Error: $10.00 SLE: 0.56 Item: Disposable Paper Fil...
# 45: Guess: $7.00 Truth: $19.99 Error: $12.99 SLE: 0.93 Item: Lid Lock Latch Switc...
# 46: Guess: $25.00 Truth: $61.25 Error: $36.25 SLE: 0.76 Item: Refrigerator Icemake...
# 47: Guess: $7.99 Truth: $14.89 Error: $6.90 SLE: 0.32 Item: Universal Washing Ma...
# 48: Guess: $19.99 Truth: $33.98 Error: $13.99 SLE: 0.26 Item: STARRICH Temperature...
# 49: Guess: $25.00 Truth: $60.06 Error: $35.06 SLE: 0.73 Item: 24 X 20 Return Air F...
# 50: Guess: $1,800.00 Truth: $512.99 Error: $1,287.01 SLE: 1.57 Item: Siemens HF224N 2 Pol...
# 51: Guess: $7.99 Truth: $10.99 Error: $3.00 SLE: 0.08 Item: Dryer Lint Filter Re...
# 52: Guess: $25.99 Truth: $23.99 Error: $2.00 SLE: 0.01 Item: Gas Range Oven Ignit...
# 53: Guess: $7.00 Truth: $13.47 Error: $6.47 SLE: 0.35 Item: SPP6 Hard Start Capa...
# 54: Guess: $25.00 Truth: $13.09 Error: $11.91 SLE: 0.38 Item: Supco Washer Water P...
# 55: Guess: $7.00 Truth: $10.50 Error: $3.50 SLE: 0.13 Item: - Dryer Thermal Cut-...
# 56: Guess: $1.00 Truth: $27.60 Error: $26.60 SLE: 7.08 Item: Electrolux Frigidair...
# 57: Guess: $7.99 Truth: $34.99 Error: $27.00 SLE: 1.92 Item: NEOUZA 51mm Bottomle...
# 58: Guess: $25.00 Truth: $34.56 Error: $9.56 SLE: 0.10 Item: / LED Lights (2) LED...
# 59: Guess: $7.99 Truth: $11.99 Error: $4.00 SLE: 0.14 Item: Upgraded 338906 Gas ...
# 60: Guess: $7.99 Truth: $7.97 Error: $0.02 SLE: 0.00 Item: OIIKI 100 PCS Univer...
# 61: Guess: $25.00 Truth: $22.77 Error: $2.23 SLE: 0.01 Item: Washer Shift Actuato...
# 62: Guess: $25.00 Truth: $10.30 Error: $14.70 SLE: 0.69 Item: Samsung Dryer Moistu...
# 63: Guess: $299.99 Truth: $229.99 Error: $70.00 SLE: 0.07 Item: Geekman Compact Clot...
# 64: Guess: $7.99 Truth: $24.40 Error: $16.41 SLE: 1.08 Item: ForeverPRO Cap for W...
# 65: Guess: $299.99 Truth: $745.90 Error: $445.91 SLE: 0.83 Item: Miroc Nugget Ice Mak...
# 66: Guess: $25.00 Truth: $36.29 Error: $11.29 SLE: 0.13 Item: Dishwasher Heating E...
# 67: Guess: $7.99 Truth: $7.99 Error: $0.00 SLE: 0.00 Item: Semetall Universal R...
# 68: Guess: $7.99 Truth: $9.99 Error: $2.00 SLE: 0.04 Item: WXJ13 2 Pack Black S...
# 69: Guess: $7.99 Truth: $31.04 Error: $23.05 SLE: 1.62 Item: Dishwasher Detergent...
# 70: Guess: $25.00 Truth: $10.99 Error: $14.01 SLE: 0.60 Item: Replacement for Aman...
# 71: Guess: $7.99 Truth: $5.91 Error: $2.08 SLE: 0.07 Item: HQRP Hepa H13 Filter...
# 72: Guess: $7.99 Truth: $23.99 Error: $16.00 SLE: 1.05 Item: Alocs MAF1 Humidifie...
# 73: Guess: $19.99 Truth: $55.78 Error: $35.79 SLE: 0.99 Item: Whole Parts Washer S...
# 74: Guess: $7.99 Truth: $6.95 Error: $1.04 SLE: 0.02 Item: High Limit Thermosta...
# 75: Guess: $1.00 Truth: $134.71 Error: $133.71 SLE: 17.79 Item: True 988290 Tempurat...
# 76: Guess: $1.50 Truth: $15.80 Error: $14.30 SLE: 3.63 Item: GENUINE Whirlpool Wh...
# 77: Guess: $1.50 Truth: $55.71 Error: $54.21 SLE: 9.74 Item: Dormont A50 1/2 Inch...
# 78: Guess: $25.00 Truth: $19.99 Error: $5.01 SLE: 0.05 Item: Silicone stove top s...
# 79: Guess: $7.00 Truth: $10.61 Error: $3.61 SLE: 0.14 Item: Whirlpool Idler Shaf...
# 80: Guess: $1.00 Truth: $10.60 Error: $9.60 SLE: 3.09 Item: Stove Knob FITS GE K...
# 81: Guess: $25.00 Truth: $49.95 Error: $24.95 SLE: 0.45 Item: Tower Manufacturing ...
# 82: Guess: $7.00 Truth: $127.96 Error: $120.96 SLE: 7.73 Item: Bloomfield Solenoid ...
# 83: Guess: $299.00 Truth: $129.99 Error: $169.01 SLE: 0.69 Item: True Induction TI-1B...
# 84: Guess: $25.00 Truth: $10.99 Error: $14.01 SLE: 0.60 Item: Replacement for Whir...
# 85: Guess: $7.00 Truth: $16.90 Error: $9.90 SLE: 0.65 Item: Dryer Idler Lever Sh...
# 86: Guess: $7.99 Truth: $34.98 Error: $26.99 SLE: 1.92 Item: UPGRADE Refrigerator...
# 87: Guess: $299.00 Truth: $500.00 Error: $201.00 SLE: 0.26 Item: Frigidaire 2 Door Ap...
# 88: Guess: $1.00 Truth: $61.57 Error: $60.57 SLE: 11.86 Item: Bunn Bypass-Plastic ...
# 89: Guess: $7.99 Truth: $12.99 Error: $5.00 SLE: 0.20 Item: Appliance Pros Dishw...
# 90: Guess: $19.99 Truth: $11.99 Error: $8.00 SLE: 0.23 Item: Washing Machine and ...
# 91: Guess: $1.00 Truth: $10.79 Error: $9.79 SLE: 3.15 Item: Supplying Demand 554...
# 92: Guess: $25.00 Truth: $23.57 Error: $1.43 SLE: 0.00 Item: Dryer Heating Elemen...
# 93: Guess: $1.50 Truth: $36.43 Error: $34.93 SLE: 7.32 Item: Frigidaire Door Rack...
# 94: Guess: $7.99 Truth: $29.75 Error: $21.76 SLE: 1.51 Item: New Refrigerator Eva...
# 95: Guess: $7.00 Truth: $106.35 Error: $99.35 SLE: 6.74 Item: General Electric WB2...
# 96: Guess: $7.99 Truth: $4.99 Error: $3.00 SLE: 0.16 Item: White Dryer Door Han...
# 97: Guess: $19.99 Truth: $6.99 Error: $13.00 SLE: 0.93 Item: Dryer Belt Replaceme...
# 98: Guess: $7.99 Truth: $23.62 Error: $15.63 SLE: 1.01 Item: Pro Tec Extended Lif...
# 99: Guess: $25.00 Truth: $158.99 Error: $133.99 SLE: 3.30 Item: Induction Cooktop, E...
# 100: Guess: $19.95 Truth: $24.95 Error: $5.00 SLE: 0.05 Item: Refrigerator Evapora...
# 101: Guess: $1.00 Truth: $14.00 Error: $13.00 SLE: 4.06 Item: Think Crucial Replac...
# 102: Guess: $25.00 Truth: $27.69 Error: $2.69 SLE: 0.01 Item: Whirlpool Pre-Filter...
# 103: Guess: $25.00 Truth: $43.03 Error: $18.03 SLE: 0.28 Item: Whirlpool SxS Refrig...
# 104: Guess: $7.99 Truth: $14.95 Error: $6.96 SLE: 0.33 Item: Reusable Keurig K Du...
# 105: Guess: $7.99 Truth: $54.95 Error: $46.96 SLE: 3.34 Item: UPGRADED Lifetime Ap...
# 106: Guess: $1,800.00 Truth: $467.81 Error: $1,332.19 SLE: 1.81 Item: KOBE Range Hoods Ins...
# 107: Guess: $25.00 Truth: $121.90 Error: $96.90 SLE: 2.41 Item: (NEW Part) compatibl...
# 108: Guess: $189.00 Truth: $129.00 Error: $60.00 SLE: 0.14 Item: Broan-NuTone Non-Duc...
# 109: Guess: $7.00 Truth: $95.99 Error: $88.99 SLE: 6.23 Item: GENUINE Frigidaire O...
# 110: Guess: $7.99 Truth: $20.89 Error: $12.90 SLE: 0.79 Item: MAF2 Humidifier Wick...
# 111: Guess: $7.99 Truth: $27.99 Error: $20.00 SLE: 1.37 Item: Stainless Steel Refi...
# 112: Guess: $7.99 Truth: $23.48 Error: $15.49 SLE: 1.00 Item: New LED Refrigerator...
# 113: Guess: $25.00 Truth: $12.99 Error: $12.01 SLE: 0.38 Item: Replacement for Whir...
# 114: Guess: $89.99 Truth: $319.99 Error: $230.00 SLE: 1.59 Item: COSTWAY Portable Was...
# 115: Guess: $7.99 Truth: $69.99 Error: $62.00 SLE: 4.27 Item: Portable Washing Mac...
# 116: Guess: $7.99 Truth: $26.99 Error: $19.00 SLE: 1.29 Item: 2-Pack Refrigerator ...
# 117: Guess: $7.99 Truth: $27.87 Error: $19.88 SLE: 1.36 Item: Siwdoy and Chrome Dr...
# 118: Guess: $7.99 Truth: $7.98 Error: $0.01 SLE: 0.00 Item: EZ SPARES Anti Vibra...
# 119: Guess: $7.99 Truth: $26.45 Error: $18.46 SLE: 1.25 Item: TOPDC 3 Prong Dryer ...
# 120: Guess: $19.99 Truth: $14.99 Error: $5.00 SLE: 0.07 Item: Washer and Dryer Cov...
# 121: Guess: $7.00 Truth: $60.59 Error: $53.59 SLE: 4.17 Item: FRIDGE CYCLE SWITCH ...
# 122: Guess: $7.99 Truth: $8.99 Error: $1.00 SLE: 0.01 Item: Nispira Activated Ch...
# 123: Guess: $7.99 Truth: $25.91 Error: $17.92 SLE: 1.20 Item: Endurance Pro Dishwa...
# 124: Guess: $7.99 Truth: $69.08 Error: $61.09 SLE: 4.22 Item: Dishwasher Center Wa...
# 125: Guess: $19.99 Truth: $45.99 Error: $26.00 SLE: 0.65 Item: Fino Pour-Over Coffe...
# 126: Guess: $25.00 Truth: $18.85 Error: $6.15 SLE: 0.07 Item: Washer Suspension Sp...
# 127: Guess: $7.99 Truth: $10.50 Error: $2.51 SLE: 0.06 Item: Walmine Black Dryer ...
# 128: Guess: $7.00 Truth: $35.99 Error: $28.99 SLE: 2.34 Item: Supplying Demand 786...
# 129: Guess: $7.99 Truth: $11.97 Error: $3.98 SLE: 0.13 Item: DI ORO MaxBrew Keuri...
# 130: Guess: $19.99 Truth: $25.99 Error: $6.00 SLE: 0.06 Item: 2-Pack Replacement W...
# 131: Guess: $7.00 Truth: $9.95 Error: $2.95 SLE: 0.10 Item: Samsung Genuine OEM ...
# 132: Guess: $19.99 Truth: $9.99 Error: $10.00 SLE: 0.42 Item: Premium Liners for N...
# 133: Guess: $25.00 Truth: $59.87 Error: $34.87 SLE: 0.72 Item: Siwdoy & Drip Pan Se...
# 134: Guess: $7.99 Truth: $12.99 Error: $5.00 SLE: 0.20 Item: Stackable Plastic Co...
# 135: Guess: $25.00 Truth: $14.97 Error: $10.03 SLE: 0.24 Item: Beaquicy Stove Burne...
# 136: Guess: $7.00 Truth: $44.63 Error: $37.63 SLE: 3.03 Item: Whirlpool Defrost Th...
# 137: Guess: $7.50 Truth: $9.97 Error: $2.47 SLE: 0.07 Item: Air Filter Factory R...
# 138: Guess: $7.99 Truth: $22.99 Error: $15.00 SLE: 0.96 Item: Rain King Range Burn...
# 139: Guess: $7.99 Truth: $15.99 Error: $8.00 SLE: 0.41 Item: (4 Pack) Reusable Co...
# 140: Guess: $7.00 Truth: $43.44 Error: $36.44 SLE: 2.94 Item: Whirlpool Burner Cap...
# 141: Guess: $299.99 Truth: $519.99 Error: $220.00 SLE: 0.30 Item: COSTWAY 24 Single Wa...
# 142: Guess: $7.99 Truth: $27.97 Error: $19.98 SLE: 1.37 Item: Replacement for Whir...
# 143: Guess: $7.99 Truth: $11.27 Error: $3.28 SLE: 0.10 Item: puxyblue & & & Dryer...
# 144: Guess: $7.99 Truth: $14.99 Error: $7.00 SLE: 0.33 Item: AQUA CREST Refrigera...
# 145: Guess: $299.99 Truth: $549.99 Error: $250.00 SLE: 0.37 Item: Tylza 15 Inch Bevera...
# 146: Guess: $299.00 Truth: $156.96 Error: $142.04 SLE: 0.41 Item: Vestynska 26lbs Ice ...
# 147: Guess: $7.99 Truth: $26.99 Error: $19.00 SLE: 1.29 Item: Stainless Steel Refi...
# 148: Guess: $25.00 Truth: $129.76 Error: $104.76 SLE: 2.61 Item: General Electric Ove...
# 149: Guess: $7.00 Truth: $60.83 Error: $53.83 SLE: 4.18 Item: Frigidaire Defrost H...
# 150: Guess: $7.99 Truth: $9.59 Error: $1.60 SLE: 0.03 Item: Blendin Replacement ...
# 151: Guess: $25.00 Truth: $165.32 Error: $140.32 SLE: 3.44 Item: 33 x 33 Or Custom Si...
# 152: Guess: $25.00 Truth: $91.78 Error: $66.78 SLE: 1.62 Item: Whole Parts Burner G...
# 153: Guess: $299.99 Truth: $99.00 Error: $200.99 SLE: 1.21 Item: BLACK+DECKER Ice Mak...
# 154: Guess: $7.99 Truth: $6.99 Error: $1.00 SLE: 0.01 Item: Allstare Grate Rubbe...
# 155: Guess: $7.99 Truth: $34.97 Error: $26.98 SLE: 1.92 Item: 2 PACK UPGRADED Refr...
# 156: Guess: $7.99 Truth: $19.34 Error: $11.35 SLE: 0.67 Item: Vicks Humidity Monit...
# 157: Guess: $25.00 Truth: $127.95 Error: $102.95 SLE: 2.56 Item: Frigidaire Oven Cont...
# 158: Guess: $7.99 Truth: $10.99 Error: $3.00 SLE: 0.08 Item: Refrigerator Door Ca...
# 159: Guess: $7.00 Truth: $39.96 Error: $32.96 SLE: 2.67 Item: Compatible Range Gas...
# 160: Guess: $7.00 Truth: $25.99 Error: $18.99 SLE: 1.48 Item: Supplying Demand Dis...
# 161: Guess: $25.00 Truth: $29.44 Error: $4.44 SLE: 0.02 Item: Warming Rack
# The Dua...
# 162: Guess: $25.00 Truth: $15.00 Error: $10.00 SLE: 0.24 Item: Eztronics CorpFor Sh...
# 163: Guess: $25.99 Truth: $17.97 Error: $8.02 SLE: 0.12 Item: Washer Pulley Clutch...
# 164: Guess: $7.99 Truth: $16.00 Error: $8.01 SLE: 0.41 Item: Siwdoy Gasket Compat...
# 165: Guess: $1,800.00 Truth: $256.44 Error: $1,543.56 SLE: 3.78 Item: Equator with Sensory...
# 166: Guess: $25.99 Truth: $36.09 Error: $10.10 SLE: 0.10 Item: UPGRADED Lifetime Ap...
# 167: Guess: $25.00 Truth: $9.99 Error: $15.01 SLE: 0.74 Item: Refrigerator Compres...
# 168: Guess: $7.99 Truth: $11.69 Error: $3.70 SLE: 0.12 Item: iSuperb 5pcs Reusabl...
# 169: Guess: $7.00 Truth: $24.00 Error: $17.00 SLE: 1.30 Item: OEM LG Dryer Lint Fi...
# 170: Guess: $7.99 Truth: $11.97 Error: $3.98 SLE: 0.13 Item: BlueStars Unbreakabl...
# 171: Guess: $25.00 Truth: $13.79 Error: $11.21 SLE: 0.32 Item: CCHUI TSD2 Start Dev...
# 172: Guess: $299.99 Truth: $380.99 Error: $81.00 SLE: 0.06 Item: Empava 30 Under Cabi...
# 173: Guess: $7.99 Truth: $9.99 Error: $2.00 SLE: 0.04 Item: CalPalmy The Exact R...
# 174: Guess: $7.99 Truth: $5.60 Error: $2.39 SLE: 0.10 Item: Rubsy Stainless Stee...
# 175: Guess: $19.99 Truth: $26.27 Error: $6.28 SLE: 0.07 Item: 𝟮𝟬𝟮𝟯 𝙐𝙥𝙜𝙧𝙖𝙙𝙚𝙙 Gas Ra...
# 176: Guess: $7.00 Truth: $10.95 Error: $3.95 SLE: 0.16 Item: GE 6-Inch Drip Pan
# P...
# 177: Guess: $7.99 Truth: $29.99 Error: $22.00 SLE: 1.53 Item: Choxila Egg Holder f...
# 178: Guess: $7.99 Truth: $15.99 Error: $8.00 SLE: 0.41 Item: Metal Stove Knob Bur...
# 179: Guess: $19.99 Truth: $9.99 Error: $10.00 SLE: 0.42 Item: 2-Pack Dryer Drum Ro...
# 180: Guess: $7.00 Truth: $12.58 Error: $5.58 SLE: 0.28 Item: Whirlpool
# Product De...
# 181: Guess: $7.99 Truth: $15.99 Error: $8.00 SLE: 0.41 Item: SWAFGSG Pour Over Co...
# 182: Guess: $7.50 Truth: $33.64 Error: $26.14 SLE: 1.97 Item: Norcold Refrigerator...
# 183: Guess: $7.50 Truth: $59.25 Error: $51.75 SLE: 3.84 Item: Epic QT 304 Brushed ...
# 184: Guess: $25.00 Truth: $7.79 Error: $17.21 SLE: 1.18 Item: Supplying Demand Clo...
# 185: Guess: $25.00 Truth: $36.43 Error: $11.43 SLE: 0.13 Item: Whynter 12 Volt DC P...
# 186: Guess: $1.50 Truth: $5.30 Error: $3.80 SLE: 0.85 Item: Harold Coffee Tools ...
# 187: Guess: $7.99 Truth: $10.99 Error: $3.00 SLE: 0.08 Item: Wfrish Cute Cow Prin...
# 188: Guess: $7.99 Truth: $11.99 Error: $4.00 SLE: 0.14 Item: 2-Pack 341241 Dryer ...
# 189: Guess: $19.99 Truth: $8.89 Error: $11.10 SLE: 0.57 Item: Dryer Idler Pulley A...
# 190: Guess: $25.00 Truth: $53.82 Error: $28.82 SLE: 0.56 Item: Whirlpool Element, B...
# 191: Guess: $7.99 Truth: $10.99 Error: $3.00 SLE: 0.08 Item: Dryer Lint Filter Re...
# 192: Guess: $7.99 Truth: $32.11 Error: $24.12 SLE: 1.70 Item: Tier1 Replacement fo...
# 193: Guess: $7.00 Truth: $59.35 Error: $52.35 SLE: 4.08 Item: Frigidaire Drain Hos...
# 194: Guess: $25.00 Truth: $9.99 Error: $15.01 SLE: 0.74 Item: Dryer Restring Heati...
# 195: Guess: $25.00 Truth: $37.13 Error: $12.13 SLE: 0.15 Item: Aprilaire 4332 Dampe...
# 196: Guess: $7.00 Truth: $34.99 Error: $27.99 SLE: 2.26 Item: Smart Choice 6-Foot ...
# 197: Guess: $7.50 Truth: $35.95 Error: $28.45 SLE: 2.16 Item: - Whirlpool Kenmore ...
# 198: Guess: $25.00 Truth: $93.06 Error: $68.06 SLE: 1.65 Item: Frigidaire Frgidaire...
# 199: Guess: $7.99 Truth: $13.99 Error: $6.00 SLE: 0.26 Item: EXCELPURE Replacemen...
# 200: Guess: $25.99 Truth: $105.99 Error: $80.00 SLE: 1.90 Item: Propane Gas Stove 2 ...
# 201: Guess: $7.63 Truth: $64.87 Error: $57.24 SLE: 4.13 Item: Porcelain Drip Pans ...
# 202: Guess: $19.99 Truth: $34.90 Error: $14.91 SLE: 0.29 Item: Culligan CUFUII Refr...
# 203: Guess: $1,800.00 Truth: $449.47 Error: $1,350.53 SLE: 1.92 Item: CPS Easy Hood - Air ...
# 204: Guess: $7.99 Truth: $16.94 Error: $8.95 SLE: 0.48 Item: Frigidaire Oven Prob...
# 205: Guess: $1,800.00 Truth: $251.07 Error: $1,548.93 SLE: 3.87 Item: Garland 208 Volt 4.1...
# 206: Guess: $7.00 Truth: $7.69 Error: $0.69 SLE: 0.01 Item: Defrost Thermostat R...
# 207: Guess: $25.00 Truth: $49.78 Error: $24.78 SLE: 0.45 Item: Uniweld Uniweld's 94...
# 208: Guess: $7.99 Truth: $29.99 Error: $22.00 SLE: 1.53 Item: PURELINE GOLD MWF Wa...
# 209: Guess: $25.00 Truth: $19.87 Error: $5.13 SLE: 0.05 Item: Refrigerator Control...
# 210: Guess: $7.99 Truth: $10.95 Error: $2.96 SLE: 0.08 Item: New Keurig Compatibl...
# 211: Guess: $7.00 Truth: $25.40 Error: $18.40 SLE: 1.43 Item: Evaporator Fan Motor...
# 212: Guess: $7.99 Truth: $3.78 Error: $4.21 SLE: 0.40 Item: Melitta M4 Cone Coff...
# 213: Guess: $25.00 Truth: $35.07 Error: $10.07 SLE: 0.11 Item: Upgraded Suspension ...
# 214: Guess: $7.00 Truth: $50.96 Error: $43.96 SLE: 3.50 Item: GE Genuine OEM High ...
# 215: Guess: $25.00 Truth: $25.99 Error: $0.99 SLE: 0.00 Item: FireFly Home Stove T...
# 216: Guess: $19.99 Truth: $13.99 Error: $6.00 SLE: 0.11 Item: GOLDEN ICEPURE Refri...
# 217: Guess: $25.00 Truth: $39.25 Error: $14.25 SLE: 0.19 Item: Clothes Dryer, Cloth...
# 218: Guess: $25.00 Truth: $73.49 Error: $48.49 SLE: 1.11 Item: GENUINE Frigidaire D...
# 219: Guess: $25.00 Truth: $97.74 Error: $72.74 SLE: 1.78 Item: Whirlpool Agitator A...
# 220: Guess: $7.99 Truth: $26.89 Error: $18.90 SLE: 1.28 Item: Range Hood Filter Re...
# 221: Guess: $1.00 Truth: $25.99 Error: $24.99 SLE: 6.77 Item: Stainless Steel Meta...
# 222: Guess: $25.99 Truth: $33.99 Error: $8.00 SLE: 0.07 Item: Washer Suspension Ro...
# 223: Guess: $25.00 Truth: $22.59 Error: $2.41 SLE: 0.01 Item: GOLDEN ICEPURE Repla...
# 224: Guess: $19.99 Truth: $13.10 Error: $6.89 SLE: 0.16 Item: Reusable Filter Cups...
# 225: Guess: $1.00 Truth: $53.99 Error: $52.99 SLE: 10.98 Item: Replacement for Refr...
# 226: Guess: $7.99 Truth: $26.77 Error: $18.78 SLE: 1.27 Item: UPGRADE Dishwasher D...
# 227: Guess: $7.99 Truth: $10.99 Error: $3.00 SLE: 0.08 Item: Dryer Lint Filter Re...
# 228: Guess: $25.00 Truth: $269.07 Error: $244.07 SLE: 5.48 Item: Frigidaire per day S...
# 229: Guess: $7.00 Truth: $18.90 Error: $11.90 SLE: 0.83 Item: Whirlpool Defrost Bi...
# 230: Guess: $7.99 Truth: $12.94 Error: $4.95 SLE: 0.19 Item: (2 Pack) Cooktop Kno...
# 231: Guess: $7.99 Truth: $11.99 Error: $4.00 SLE: 0.14 Item: Reusable Keurig K Cu...
# 232: Guess: $25.00 Truth: $123.98 Error: $98.98 SLE: 2.47 Item: Thermador Water Filt...
# 233: Guess: $7.99 Truth: $68.66 Error: $60.67 SLE: 4.19 Item: LG Genuine OEM Door ...
# 234: Guess: $1.50 Truth: $54.99 Error: $53.49 SLE: 9.67 Item: HARIO V60 Coffee Fil...
# 235: Guess: $7.99 Truth: $9.99 Error: $2.00 SLE: 0.04 Item: SHANOER Replacement ...
# 236: Guess: $7.00 Truth: $23.59 Error: $16.59 SLE: 1.26 Item: Frigidaire Splash Sh...
# 237: Guess: $25.00 Truth: $27.99 Error: $2.99 SLE: 0.01 Item: Dryer Repair Kit Com...
# 238: Guess: $25.99 Truth: $9.46 Error: $16.53 SLE: 0.90 Item: UPGRADED 285811 Medi...
# 239: Guess: $25.00 Truth: $105.99 Error: $80.99 SLE: 2.00 Item: Washer Tub Bearing I...
# 240: Guess: $299.99 Truth: $769.00 Error: $469.01 SLE: 0.88 Item: EdgeStar Full Size D...
# 241: Guess: $25.00 Truth: $76.99 Error: $51.99 SLE: 1.21 Item: Supplying Demand Fro...
# 242: Guess: $7.99 Truth: $39.96 Error: $31.97 SLE: 2.30 Item: JMSWENJUAN 48 Capaci...
# 243: Guess: $7.99 Truth: $7.99 Error: $0.00 SLE: 0.00 Item: Dryer Idler Pulley R...
# 244: Guess: $25.00 Truth: $12.99 Error: $12.01 SLE: 0.38 Item: Washer And Dryer Cov...
# 245: Guess: $1.00 Truth: $25.95 Error: $24.95 SLE: 6.76 Item: Frigidaire Range Bur...
# 246: Guess: $25.99 Truth: $19.79 Error: $6.20 SLE: 0.07 Item: Washing Machine Base...
# 247: Guess: $25.00 Truth: $165.99 Error: $140.99 SLE: 3.46 Item: Frigidaire Genuine O...
# 248: Guess: $25.00 Truth: $12.99 Error: $12.01 SLE: 0.38 Item: Replacement for Sams...
# 249: Guess: $19.99 Truth: $41.99 Error: $22.00 SLE: 0.51 Item: Refrigmatic Electron...
# 250: Guess: $1.00 Truth: $151.91 Error: $150.91 SLE: 18.81 Item: Cleveland Transforme...
